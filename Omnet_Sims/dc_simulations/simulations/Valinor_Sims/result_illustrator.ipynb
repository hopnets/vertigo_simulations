# %% [markdown]
# In this document we shortly compare the trends in the results of small scale simulations and results illustrated in the paper. You can see that the trends in mean Query Completion Times (QCT), tail QCT, mean Flow Completion Times (FCT), tail FCT

# %%
from IPython.display import Image, display

display(Image(filename="figs/{}.png".format('simple_mean_fct')))
display(Image(filename="paper_figs/{}.png".format('qps25fct')))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_3863/3191427738.py in <module>
#       2
#       3 display(Image(filename="figs/{}.png".format('simple_mean_fct')))
# ----> 4 display(Image(filename="paper_figs/{}.png".format('mean_fct')))
#
# ~/.local/lib/python3.7/site-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1230         self.unconfined = unconfined
#    1231         super(Image, self).__init__(data=data, url=url, filename=filename,
# -> 1232                 metadata=metadata)
#    1233
#    1234         if self.width is None and self.metadata.get('width', {}):
#
# ~/.local/lib/python3.7/site-packages/IPython/core/display.py in __init__(self, data, url, filename, metadata)
#     635             self.metadata = {}
#     636
# --> 637         self.reload()
#     638         self._check_data()
#     639
#
# ~/.local/lib/python3.7/site-packages/IPython/core/display.py in reload(self)
#    1261         """Reload the raw data from file or URL."""
#    1262         if self.embed:
# -> 1263             super(Image,self).reload()
#    1264             if self.retina:
#    1265                 self._retina_shape()
#
# ~/.local/lib/python3.7/site-packages/IPython/core/display.py in reload(self)
#     660         """Reload the raw data from file or URL."""
#     661         if self.filename is not None:
# --> 662             with open(self.filename, self._read_flags) as f:
#     663                 self.data = f.read()
#     664         elif self.url is not None:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'paper_figs/mean_fct.png'

# %% [markdown]
# Figures above compare the trends seen in mean Flow Completion

# %%
display(Image(filename="figs/{}.png".format('simple_tail_fct')))
display(Image(filename="paper_figs/{}.png".format('qps25tcpp99fct')))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_3863/2372326850.py in <module>
#       1 display(Image(filename="figs/{}.png".format('simple_tail_fct')))
# ----> 2 display(Image(filename="paper_figs/{}.png".format('tail_fct')))
#
# ~/.local/lib/python3.7/site-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1230         self.unconfined = unconfined
#    1231         super(Image, self).__init__(data=data, url=url, filename=filename,
# -> 1232                 metadata=metadata)
#    1233
#    1234         if self.width is None and self.metadata.get('width', {}):
#
# ~/.local/lib/python3.7/site-packages/IPython/core/display.py in __init__(self, data, url, filename, metadata)
#     635             self.metadata = {}
#     636
# --> 637         self.reload()
#     638         self._check_data()
#     639
#
# ~/.local/lib/python3.7/site-packages/IPython/core/display.py in reload(self)
#    1261         """Reload the raw data from file or URL."""
#    1262         if self.embed:
# -> 1263             super(Image,self).reload()
#    1264             if self.retina:
#    1265                 self._retina_shape()
#
# ~/.local/lib/python3.7/site-packages/IPython/core/display.py in reload(self)
#     660         """Reload the raw data from file or URL."""
#     661         if self.filename is not None:
# --> 662             with open(self.filename, self._read_flags) as f:
#     663                 self.data = f.read()
#     664         elif self.url is not None:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'paper_figs/tail_fct.png'

# %%
display(Image(filename="figs/{}.png".format('simple_mean_qct')))
display(Image(filename="paper_figs/{}.png".format('qps25')))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_3863/32346798.py in <module>
#       1 display(Image(filename="figs/{}.png".format('simple_mean_qct')))
# ----> 2 display(Image(filename="paper_figs/{}.png".format('mean_qct')))
#
# ~/.local/lib/python3.7/site-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1230         self.unconfined = unconfined
#    1231         super(Image, self).__init__(data=data, url=url, filename=filename,
# -> 1232                 metadata=metadata)
#    1233
#    1234         if self.width is None and self.metadata.get('width', {}):
#
# ~/.local/lib/python3.7/site-packages/IPython/core/display.py in __init__(self, data, url, filename, metadata)
#     635             self.metadata = {}
#     636
# --> 637         self.reload()
#     638         self._check_data()
#     639
#
# ~/.local/lib/python3.7/site-packages/IPython/core/display.py in reload(self)
#    1261         """Reload the raw data from file or URL."""
#    1262         if self.embed:
# -> 1263             super(Image,self).reload()
#    1264             if self.retina:
#    1265                 self._retina_shape()
#
# ~/.local/lib/python3.7/site-packages/IPython/core/display.py in reload(self)
#     660         """Reload the raw data from file or URL."""
#     661         if self.filename is not None:
# --> 662             with open(self.filename, self._read_flags) as f:
#     663                 self.data = f.read()
#     664         elif self.url is not None:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'paper_figs/mean_qct.png'

# %%
display(Image(filename="figs/{}.png".format('simple_tail_qct')))
display(Image(filename="paper_figs/{}.png".format('qps25p99qct')))
